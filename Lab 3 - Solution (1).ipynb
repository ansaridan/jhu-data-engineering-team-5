# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Lab 3 - Visualization - Solution

# %%
# %matplotlib inline

# %% [markdown]
# The special command above will make all the `matplotlib` images appear in the notebook.

# %% [markdown]
# ## General Instructions
#
# In this course, Labs are the chance to applying concepts and methods discussed in the module.
# They are a low stakes (pass/fail) opportunity for you to try your hand at *doing*.
# Please make sure you follow the general Lab instructions, described in the Syllabus.
# The summary is:
#
# * Discussions should start as students work through the material, first Wednesday at the start of the new Module week.
# * Labs are due by Sunday.
# * Lab solutions are released Monday.
# * Post Self Evaluation and Lab to Lab Group on Blackboard and Lab to Module on Blackboard on Monday.
#
# The last part is important because the Problem Sets will require you to perform the same or similar tasks without guidance.
# Problem Sets are your opportunity to demonstrate that you understand how to apply the concepts and methods discussed in the relevant Modules and Labs.

# %% [markdown]
# ## Specific Instructions
#
# 1.  For Blackboard submissions, if there are no accompanying files, you should submit *only* your notebook and it should be named using *only* your JHED id: fsmith79.ipynb for example if your JHED id were "fsmith79". If the assignment requires additional files, you should name the *folder/directory* your JHED id and put all items in that folder/directory, ZIP it up (only ZIP...no other compression), and submit it to Blackboard.
#
#     * do **not** use absolute paths in your notebooks. All resources should located in the same directory as the rest of your assignments.
#     * the directory **must** be named your JHED id and **only** your JHED id.
#     * do **not** return files provided by us (data files, .py files)
#
#
# 2. Data Science is as much about what you write (communicating) as the code you execute (researching). In many places, you will be required to execute code and discuss both the purpose and the result. Additionally, Data Science is about reproducibility and transparency. This includes good communication with your team and possibly with yourself. Therefore, you must show **all** work.
#
# 3. Avail yourself of the Markdown/Codecell nature of the notebook. If you don't know about Markdown, look it up. Your notebooks should not look like ransom notes. Don't make everything bold. Clearly indicate what question you are answering.
#
# 4. Submit a cleanly executed notebook. The first code cell should say `In [1]` and each successive code cell should increase by 1 throughout the notebook.
#
# **There are only 4 charts because we expect depth rather than breadth**

# %%
import numpy as np
import random as py_random
import numpy.random as np_random
import time
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %%
THEME = "darkslategray"

# %% [markdown]
# <div style="background: lemonchiffon; margin:20px; padding: 20px;">
#     <strong>Note</strong>
#     <p>Defining your main color in a variable makes it easier when your boss says, "can you make these all blue?".</p>
# </div>

# %% [markdown]
# ## Data Visualization
#
# Here are four (4) Charts we want you to analyze.
# There are only four charts because we want you to be thorough and, based on the materials from the Module, sophisticated in your analysis.
# You should not answer now nor on any future assignment, "because pie charts are bad" or "because we've been told not to use pie charts".
# Please make sure you check the Solution on Monday and compare it to your own.
#
# Some of these charts work as "infographics" but we want you to evaluate them as if they were slides to be presented to the CEO, that is, a data science presentation.
# (Those kinds of slides don't find their way onto Google).

# %% [markdown]
# ### Chart 1
#
# 1. What do you think the main story of the chart is? Does the chart really tell it? Identify any secondary stories.
# 2. Discuss how the chart either adheres to or violates the principles discussed in the module (Cleveland, Ware, and Gestalt).
# 3. Discuss at least two alternative charts that follow the guidelines presented in the module.
# 4. Create one of those alternatives by decoding the values as best you as you can and using `matplotlib` (you may use `seaborn` only to change the formatting).
#
# You may insert as many Markdown and Code cells below each chart as you need.

# %% [markdown]
# <img src="data:image/jpeg;base64,..." width="50%"/>

# %% [markdown]
# 1. In *Fundamentals*, we talked about the Eight (8) Quantitative Relationships/Stories, which one is this? It appears to be Ranking so we can say that this is a Ranking story of total sales of various fast food chains.
# There is also a comparison with the GDP of Afghanistan.
# It's not entirely clear why that is a good comparison (you often see them) because (a) most Americans can't place Afghanistan on a map and (b) even if they can, it's not clear why Afghanistan is a relevant context.
# Finally, why \\$21 billion as that context?
#
#     As for the secondary stories, we could reverse the Ranking story here to be from largest to smallest.
#     We could also tell a Difference story if that were important (what if you worked for KFC...that might be the baseline).
#     If these were *all* the fast food chains, we could tell a Part/Whole story of market share (although not all of these are perfect substitutes for each other).
#
# 2. We know that for a Ranking story (relationship) that a bar chart is one option.
# In this case, they did start the y-axis at 0.
# Additionally, the values are sorted which lead us to compare increasing values.
#
#     However, they have fallen prey to the siren's call of "chart chunk" and, in so doing, have violated the width constraint on bar charts: all the bars must be the same width.
#     The next problem--purely from a visualization point of view which you should adhere to in this class--it includes value labels.
#     If you have a story that can be visualized, it should only be a visualization.
#     If you need to communicate the values *also* then they should be in an accompanying table.
#
# 3. If we still want to tell the Ranking story, we can keep with a bar chart but use correct (fixed width) bars.
# If we want to tell more of a Deviation story, we can either transform the data into differences (from KFC, for example) and use bars or use points (and change the axis).

# %%
sales = [4.1, 4.3, 8.0, 8.2, 9.4, 11.3, 41.0]
chain = ["Starbucks", "Taco Bell", "Pizza Hut", "KFC", "Wendy's", "Burger King", "McDonalds"]
width = 1/1.5

figure = plt.figure(figsize=(10, 6)) # first element is width, second is height.

axes = figure.add_subplot(1, 1, 1)

axes.set_title( "McDonald's Outpaces Competitors in Global Sales")
axes.bar(range(0, len(sales)), sales, width, color=THEME, align="center")
axes.set_xticks(range(0, len(sales)))
axes.set_xticklabels(chain)
axes.yaxis.grid( b=True, which="major")
axes.set_ylim((0, 50))
axes.set_ylabel( "Sales in Billions US $")

plt.show()

# %% [markdown]
# <div style="background: lemonchiffon; margin:20px; padding: 20px;">
#     <strong>Note</strong>
# <p>Most of the solutions to being a "bad chart" are going to be either creating a bar/line/point chart or just using a table instead.
# Sometimes it's even just a statement, a sentence.
#     This does't mean that charts need to be boring.</p>
#
# <p>For a newspaper, this could certainly be dressed up a bit by either varying the background, bar or line colors.
# It might be appropriate to do so in the usual "theme" of the newspaper.
# We could add a logo to the bars as long as it doesn't change the width or height of the bars.
# For a data science presentation, this is probably sufficient. I prefer chart titles that communicate the message.</p>
#
# <p>I couldn't find a good contextual comparison.
# My guess is that originally the idea was to "put the money in context, wow, this is more than the GDP of Afghanistan!"
# I looked at states but the smallest state, Vermont, had a GSP of \$29.8 billion and that seemed a bit high.
# It would be nice to find a context at around the \$10 billion mark and the \$40 billion mark.</p>
#
# <p>I think the best context might be something related to food...perhaps a regular sit down chain like Olive Garden.
# Perhaps you could make it <em>per capita</em> (or something) and contrast with spending on groceries for a family of four.</p>
#
# <p>Finally, I don't know when the chart was produced, but it would be interesting to update it. For example, <a href="https://www.qsrmagazine.com/content/qsr50-2020-top-50-chart">2020 Data</a> can be found here although the CSS layout is awful.</p>
#
# </div>
#
#
# <div style="background: peachpuff; margin:20px; padding: 20px;">
#     <strong>Rubric</strong>
#     <ul>
#         <li>A story (primary or secondary) should always <i>start</i> with one of the eight (8) quantitative relationships. If you don't, that's wrong.</li>
#         <li>You must be specific and technical when talking about the deficiencies of the chart. Cite the specific problem from the research.</li>
#         <li>You must not use color haphazardly or for "fun". This is discussed in the text. Use a neutral color as the examples do.</li>
#     </ul>
# </div>

# %% [markdown]
# ### Chart 2
#
# 1. What do you think the main story of the chart is? Does the chart really tell it? Identify any secondary stories.
# 2. Discuss how the chart either adheres to or violates the principles discussed in the module (Cleveland, Ware, and Gestalt).
# 3. Discuss at least two alternative charts that follow the guidelines presented in the module.
# 4. Create one of those alternatives by decoding the values as best you as you can and using `matplotlib` (you may use `seaborn` only to change the formatting).
#
# You may insert as many Markdown and Code cells below each chart as you need.
# You may insert as many Markdown and Code cells below each chart as you need.

# %% [markdown]
# <img width="750" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# 1. There are several stories explicitly identified:
#
#     (a) The main story is a Part/Whole relationship: a large percentage of specific foods that Americans eat are imported (the "whole" is all foods Americans eat and the "part" is those that are imported).
#     This is actually a *set* of Part/Whole relationships.
#     In other words, the five charts are sort of "small multiples" telling a Part/Whole story for each of five categories of food.
#     (b) The other main story is yet another set of Part/Whole stories: Mexico, Chile, Canada, China, and Vietnam are the largest exporters for certain foods. There is also a set of Part/Whole stories told for three categories of food.
#     (c) Another secondary story a Time Series: that food imports have doubled in the last 10 years (2002 to 2012).
#     (d) One final Part/Whole story is that is the claim that a full 20% Of foods that Americans eat are imported.
#
# 2. Overall, this is probably a reasonable infographic but if you try end up in this direction in a business setting, you probably need to rethink your approach.
# Additionally, they do explicitly call out the stories they're trying to tell.
# Finally, for some stories, they don't attempt to make a weird table...they just make a statement.
# For some reason, we often feel that a chart or table is required.
# Do you really need a chart or table that shows imports in 2002 and imports in 2012 so you can see that imports doubled or can I just tell you that imports doubled?
# It will depend on the context but sometimes textual statements are just fine.
#
#     However, The chart fails in several ways.
#     The images are not good pie charts and there's no way you could get those percentages off the images.
#     I can't tell that that's 61% of a honey comb.
#     Is the strawberry included with the peach or just decoration?
#     So this isn't just a case of "Cleveland's research demonstrated that angles are more difficult to decode", they're *bad* pie charts.
#     Why is there a category "fruits and nuts" and "vegetables and melons".
#     Isn't a melon a fruit?
#
#     The flags are interesting but unless you know the flags it is just decoration.
#     They're not bars so all of the information comes from the table.
#     That actually might be okay but the main issue is that we're left wondering who the other exporters are.
#     For example, for the third one, China and Vietnam only account for 22.5% of the imports.
#
#     Finally, it would be nicer if the statements included the data.
#     For example, "over the last decade, food imports increased from \\$XX billion to \\$YY billion".
#
# 3. For the main story "large percentage are imported", a bar chart is probably the best.
# This becomes a Ranking story.
# If we wish to stay with a Part/Whole story, then we could have four bar charts as "small multiples".
# A bar chart is also a good choice for the "major importers" story but I feel like we don't really have enough data to make a decent chart.
# In this case, we would have small multiples of bar charts that include all of the exporting countries up to some threshold and then just have a final "Rest of the World" category.
# This would keep the Part/Whole Story.
#
# 4. Here we provide an example that combines the "1/5th of what Americans eat is imported" Part/Whole story into a chart title and then turn the "large percentages of these foods" story from a set of Part/Whole stories into a single Ranking story.

# %%
percent = [20.0, 51.0, 52.0, 61.0, 88.0]
food = ["Vegetables/Melons", "Fruits & Nuts", "Lamb", "Honey", "Seafood"]
width = 1/1.5

figure = plt.figure(figsize=(10, 6)) # first element is width, second is height.

axes = figure.add_subplot(1, 1, 1)

axes.set_title( "20% of what Americans eat is Imported")
axes.bar(range(0, len(percent)), percent, width, color=THEME, align="center")
axes.set_xticks(range(0, len(percent)))
axes.set_xticklabels(food)
axes.yaxis.grid( b=True, which="major")
axes.set_ylim((0, 100))
axes.set_ylabel( "Percent Imported")

plt.show()

# %% [markdown]
# <div style="background: lemonchiffon; margin:20px; padding: 20px;">
#     <strong>Note</strong>
#     <p>Again, this probably works as an infographic although it takes a lot of ink to tell a simple set of stories.
# I might have liked to have seem more data than pictures of fish.
# The main point of using this image was to emphasize collections of stories and the possibility of making statements as an alternative to tables or charts.
# </p>
#     <p><strong>IMPORTANT: when copying code from <em>Fundamentals</em> or the Labs, make sure you change the variable names and labels.</strong></p>
# </div>
#
#
# <div style="background: peachpuff; margin:20px; padding: 20px;">
#     <strong>Rubric</strong>
#     <ul>
#         <li>A story (primary or secondary) should always <i>start</i> with one of the eight (8) quantitative relationships. If you don't, that's wrong.</li>
#         <li>You must be specific and technical when talking about the deficiencies of the chart. Cite the specific problem from the research.</li>
#         <li>You must not use color haphazardly or for "fun". This is discussed in the text. Use a neutral color as the examples do.</li>
#         <li>Because there are so many options for this particular problem, there is some leeway in terms of what, exactly, you decided to chart, as long as you charted something and explain why you picked that particular story.</li>
#     </ul>
# </div>

# %% [markdown]
# ### Chart 3
#
# 1. What do you think the main story of the chart is? Does the chart really tell it? Identify any secondary stories.
# 2. Discuss how the chart either adheres to or violates the principles discussed in the module (Cleveland, Ware, and Gestalt).
# 3. Discuss at least two alternative charts that follow the guidelines presented in the module.
# 4. Create one of those alternatives by decoding the values as best you as you can and using `matplotlib` (you may use `seaborn` only to change the formatting).
#
# You may insert as many Markdown and Code cells below each chart as you need.

# %% [markdown]
# <img width="750" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# 1. This is a story about Deviation, in terms of a possible change to the drinking age in Saskatchewan.
# The point is to contrast what Saskatchewan's drinking age was, what it might have been, and that it will continue to be the same.
# There's an interesting secondary Deviation story hidden in the statement: the *neighboring* provinces of Alberta and Manitoba both have a lower drinking age.
# You have to know Canadian geography, however (which we assume Canadians do!).
#
# 2. The chart is odd because it's not entirely clear that we need a chart for this information at all.
# And the main theme/thrust of the story is delivered in text.
# We could just say, "Although the drinking age in Sasktachewan's neighbors is 18 years of age, the drinking age in Sasktachewan will remain 19, in line with the remainder of the Canadian provinces except Quebec."
# We might also create a table since only 50% of the story is explicitly in the chart anyway.
# However, the authors felt the information was sufficiently important to call it out in a statement.
#
#     It's clear that the bars don't start at 0 (no pun intended).
#     However, this seems to be a weird case, since we are talking about a Deviation story, focus appears to be on the gaps between bars rather than the heights of the bars.
#
#     It's also completely strange that the values are integers (counts) for 18 and 19 but the y-axis scale includes irrelevant fractional amounts and doesn't include either 18 or 19! Having just 18 and 19 on the y-axis would have completely negated the need for data annotations on the bars.
#
# 3. The obvious choice here is a color coded map (chloropleth).
# If one doesn't do a map, the other options are (a) a statement, or (b) a table, or (c) a chart.
# I think that a chloropleth was the obvious choice here and someone couldn't figure out how to do a small map of Canada quickly.
# If they weren't going to use a map, one missed opportunity was to arrange the bars geographically, from left to right.
# We can then add annotations about the proposed change that failed.
# Additionally, we can assume this was for a Canadian audience so we can use official province abbreviations the same way we'd use official state abbreviations if we were doing a chart of the United States.

# %%
count = [19, 19, 19, 18, 19, 18, 19, 19, 19, 18, 19, 19, 19]
age = ["YT", "BC", "NT", "AB", "SK", "MB", "NU", "ON", "QC", "NB", "NS", "NL", "PE"]
width = 1/1.5

figure = plt.figure(figsize=(6, 4)) # first element is width, second is height.

axes = figure.add_subplot(1, 1, 1)

axes.set_title( "Drinking age will remain 19 in Saskatchewan")
axes.bar(range(0, len(count)), count, width, color=THEME, align="center", alpha=.75)
axes.set_xticks(range(0, len(count)))
axes.set_xticklabels(age)
axes.yaxis.set_ticks(range(0, 21, 5))
axes.set_ylim((0, 20))
axes.set_ylabel( "Drinking Age")
axes.set_xlabel( "Provinces")

plt.show()

# %% [markdown]
# As a chart, this isn't very satisfying.
# Let's try a table:
#
# | Province                                       | Drinking Age |
# |------------------------------------------------|--------------|
# | YT, BC, NT, AB, NU, ON, NB, NS, NL, PE         | 19           |
# | AB, MB, QC                                     | 18           |
# | SK                                             | 19           |

# %% [markdown]
# This is a great site for generating Markdown tables: [Markdown Table Generator](https://www.tablesgenerator.com/markdown_tables).

# %% [markdown]
# <div style="background: peachpuff; margin:20px; padding: 20px;">
#     <strong>Rubric</strong>
#     <ul>
#         <li>A story (primary or secondary) should always <i>start</i> with one of the eight (8) quantitative relationships. If you don't, that's wrong.</li>
#         <li>You must be specific and technical when talking about the deficiencies of the chart. Cite the specific problem from the research.</li>
#         <li>You must not use color haphazardly or for "fun". This is discussed in the text. Use a neutral color as the examples do.</li>
#     </ul>
# </div>

# %% [markdown]
# ### Chart 4
# 1. What do you think the main story of the chart is? Does the chart really tell it? Identify any secondary stories.
# 2. Discuss how the chart either adheres to or violates the principles discussed in the module (Cleveland, Ware, and Gestalt).
# 3. Discuss at least two alternative charts that follow the guidelines presented in the module.
# 4. Create one of those alternatives by decoding the values as best you as you can and using `matplotlib` (you may use `seaborn` only to change the formatting).
#
# You may insert as many Markdown and Code cells below each chart as you need.

# %% [markdown]
# <img width="750" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# 1. The main story here is a Time Series story about the the trend of the Unemployment Rate under President Obama in 2011. The chart tells the story fairly well except for a "data entry error" for the last number.
# We could also tell a Deviation story, taking January 2011 as the starting point.
#
# 2. The chart has two main problems.
# First, the final 8.6% value is not correctly charted.
# Second, because of the shading, the line chart has become an area chart and the y-axis needs to start at 0.
# As a general rule, there should be no value annotations included but we're kind of lucky here that they did.
# I would say this rule applies to most business/data science presentations but not necessarily to infographics, which is what we have here.
#
# 3. We could make this as a line chart and have the y-axis start at 8% as it does now or we could have this as an area chart and have the y-axis start at zero.
# Let's try both.
# We can also add an informative title.

# %%
percent = [9.0, 8.9, 8.8, 9.0, 9.1, 9.2, 9.1, 9.1, 9.1, 9.0, 8.6]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov"]
xs = list(range( 1, len(months)+1))

figure = plt.figure(figsize=(10, 6)) # first element is width, second is height.

axes = figure.add_subplot(1, 1, 1)

axes.set_title( "Unemployment Rate Under Obama at its lowest for 2011")
axes.plot(xs, percent, "o-", color=THEME)
#axes.vlines(xs, [0], percent, linestyles='dotted', lw=2)
axes.set_xticks(xs)
axes.set_xlim((0, len( months)+1))
axes.set_ylim((8, 10))
axes.set_xticklabels(months)
axes.xaxis.grid(False)
axes.set_ylabel( "Unemployment Rate (%)")

plt.show()

# %% [markdown]
# A lot of charts involving time involve judgment. For example, we generally use bar charts for the months or quarters of a single year or years of a few years but switch to line charts for many years but not always.
#
# Keeping a non-zero y-axis start and switching to a bar chart *style*, requires using dots. I'm ambivalent about dot charts because they're not really that common. In the chart below, I used a line chart. Because the area of the line is not shaded, we do not have to start at 0.

# %%
figure = plt.figure(figsize=(10, 6)) # first element is width, second is height.

axes = figure.add_subplot(1, 1, 1)

axes.set_title( "Unemployment Rate Under Obama at its lowest for 2011")
axes.plot(xs, percent, "o-", color=THEME)
axes.set_xticks(xs)
axes.set_xlim((0, len( months)+1))
axes.set_ylim((0, 10))
axes.set_xticklabels(months)
axes.xaxis.grid(False)
axes.set_ylabel( "Unemployment Rate (%)")
axes.fill_between(range(1, 12), percent, color=THEME, alpha=0.5)
plt.show()

# %% [markdown]
# <div style="background: lemonchiffon; margin:20px; padding: 20px;">
#     <strong>Note</strong>
#     <p>Time can be tricky because there are no hard and fast rules about where we switch from bar charts to line charts, it's just that at some point, there's so much data that we do.
# It can also be dictated by the explicit or implicit sense of continuity.
# </p>
#     <p>It's common to see months as both line and bar charts, which emphasizes this "Problem of the Heaps" (how many beans does it take to be a "heap" of beans?)
# </div>
#
#
# If you did a bar chart, that's ok as long as you started at 0:

# %%
percent = [9.0, 8.9, 8.8, 9.0, 9.1, 9.2, 9.1, 9.1, 9.1, 9.0, 8.6]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov"]
xs = list(range( 1, len(months)+1))

figure = plt.figure(figsize=(6, 4)) # first element is width, second is height.

axes = figure.add_subplot(1, 1, 1)

axes.set_title( "Unemployment Rate Under Obama at its lowest for 2011")
axes.bar(range(0, len(months)), percent, width, color=THEME, align="center", alpha=.75)
axes.set_xticks(range(0, len(months)))
axes.set_ylim((0, 10))
axes.set_xticklabels(months)
axes.set_ylabel( "Unemployment Rate (%)")


plt.show()

# %% [markdown]
# <div style="background: peachpuff; margin:20px; padding: 20px;">
#     <strong>Rubric</strong>
#     <ul>
#         <li>A story (primary or secondary) should always <i>start</i> with one of the eight (8) quantitative relationships. If you don't, that's wrong.</li>
#         <li>You must be specific and technical when talking about the deficiencies of the chart. Cite the specific problem from the research.</li>
#         <li>You must not use color haphazardly or for "fun". This is discussed in the text. Use a neutral color as the examples do.</li>
#         <li>If you did a bar chart, it must start at 0.</li>
#         <li>If you did an area chart (shading under a line chart), it must start at 0.</li>
#     </ul>
# </div>
